# %% [markdown]
# # Compilation of math expressions

# %%
import numpy as np
import matplotlib.pyplot as plt
t = np.arange(0.0, 2.0, 0.01)
s = np.sin(2*np.pi*t)

plt.plot(t,s)
plt.title(r'$\alpha_i > \beta_i$', fontsize=20)
plt.text(1, -0.6, r'$\sum_{i=0}^\infty x_i$', fontsize=20)
plt.text(0.6, 0.6, r'$\mathcal{A}\mathrm{sin}(2 \omega t)$',
         fontsize=20)
plt.xlabel('time (s)')
plt.ylabel('volts (mV)')
plt.show()

# %%
# math text
plt.title(r'$\alpha > \beta$')
# Out:
# Text(0.5,1,'$\\alpha > \\beta$')

# %%
# %%latex
# $\alpha_i > \beta_i$
# Out:
# $\alpha_i > \beta_i$

# %%
# %%latex
# $\sum_{i=0}^\infty x_i$
# Out:
# $\sum_{i=0}^\infty x_i$

# %%
# %%latex
# $\frac{3}{4} \binom{3}{4} \stackrel{3}{4}$
# Out:
# $\frac{3}{4} \binom{3}{4} \stackrel{3}{4}$

# %%
from IPython.display import IFrame
IFrame('https://matplotlib.org/users/mathtext.html', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://matplotlib.org/users/mathtext.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# # IPython.display has IFrame, Image, Math, Latex, and YouTubeVideo

# %%
from IPython.display import IFrame
IFrame('https://en.wikipedia.org/wiki/Meme', width='100%', height=350)
# Out:
#         <iframe
#             width="100%"
#             height="350"
#             src="https://en.wikipedia.org/wiki/Meme"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
from IPython.display import Image
img_url = 'https://i.redd.it/2jh2ngxu6o911.png'
Image(img_url)

# %%
from IPython.display import Math
Math(r'F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx')
# Out:
# $$F(k) = \int_{-\infty}^{\infty} f(x) e^{2\pi i k} dx$$

# %%
from IPython.display import Latex
Latex(r"""\begin{eqnarray}
\nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
\nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
\nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
\nabla \cdot \vec{\mathbf{B}} & = 0 
\end{eqnarray}""")
# Out:
# \begin{eqnarray}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{eqnarray}

# %% [markdown]
# ## Or just use %%latex

# %%
# %%latex
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}
# Out:
# \begin{align}
# \nabla \times \vec{\mathbf{B}} -\, \frac1c\, \frac{\partial\vec{\mathbf{E}}}{\partial t} & = \frac{4\pi}{c}\vec{\mathbf{j}} \\
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('w7x_lWJNnNg')

# %%
# %%latex
# $s(t) = \mathcal{A}\mathrm{sin}(2 \omega t)$
# Out:
# $s(t) = \mathcal{A}\mathrm{sin}(2 \omega t)$

# %%
# %%latex
# $s(t) = \mathcal{A}\sin(2 \omega t)$
# Out:
# $s(t) = \mathcal{A}\sin(2 \omega t)$

# %%
# %%latex
# $s(t) = \mathcal{A}\/\sin(2 \omega t)$
# Out:
# $s(t) = \mathcal{A}\/\sin(2 \omega t)$
